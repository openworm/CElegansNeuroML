# %%
import os
import sys
os.chdir("../..") 

# %matplotlib inline
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = (20.0, 15.0)

from runAndPlot import run_c302

# %%
cells, cells_to_stimulate, params, muscles = run_c302('AVA_VA','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVA")
# Out:
# ********************
#
#    Going to generate c302_C2_AVA_VA and run for 4000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C
# Set default parameters for C2
# Opened file: /home/david.lung/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# Opened file: /home/david.lung/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# c302      >>>  Positioning muscle: MDR01 at (80,-270,80)
# c302      >>>  Positioning muscle: MDR02 at (80,-240,80)
# c302      >>>  Positioning muscle: MDR03 at (80,-210,80)
# c302      >>>  Positioning muscle: MDR04 at (80,-180,80)
# c302      >>>  Positioning muscle: MDR05 at (80,-150,80)
# c302      >>>  Positioning muscle: MDR06 at (80,-120,80)
# c302      >>>  Positioning muscle: MDR07 at (80,-90,80)
# c302      >>>  Positioning muscle: MDR08 at (80,-60,80)
# c302      >>>  Positioning muscle: MDR09 at (80,-30,80)
# c302      >>>  Positioning muscle: MDR10 at (80,0,80)
# ...

# %%
config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
config_param_overrides = {
    'conn_number_override': {
        'AVBL_GJ-VB1': 1*0,
        'AVBL_GJ-VB2': 14*0,
        'AVBR_GJ-VB2': 6*0,
        'AVBR_GJ-VB3': 7*0,
        'AVBL_GJ-VB4': 3*0,
        'AVBR_GJ-VB4': 5*0,
        'AVBL_GJ-VB5': 3*0,
        'AVBR_GJ-VB5': 3*0,
        'AVBL_GJ-VB6': 3*0,
        'AVBR_GJ-VB6': 4*0,
        'AVBL_GJ-VB7': 4*0,
        'AVBR_GJ-VB7': 3*0,
        'AVBL_GJ-VB8': 3*0,
        'AVBR_GJ-VB8': 4*0,
        'AVBL_GJ-VB9': 4*0,
        'AVBR_GJ-VB9': 3*0,
        'AVBL_GJ-VB10': 3*0,
        'AVBR_GJ-VB10': 4*0,
        'AVBL_GJ-VB11': 5*0,
        'AVBR_GJ-VB11': 6*0,
    }
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_neuron_elec_syn_gbase": "0.00952 nS"}
config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_neuron_elec_syn_gbase": "0.00952 nS",
                   "neuron_to_muscle_exc_syn_conductance": "0.12 nS"}
config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.17 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.017 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.49 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.007 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.49 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.007 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.39 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.007 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.49 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.29 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.007 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.39 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.29 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.007 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.59 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.017 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.59 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.037 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.69 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.047 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.69 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.037 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.79 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.047 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.79 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.17 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.037 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.69 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.037 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.69 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.39 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance": "0.07 nS",
                  "neuron_to_muscle_inh_syn_conductance": "0.037 nS",
                  "neuron_to_neuron_exc_syn_conductance": "0.59 nS",
                  "neuron_to_neuron_inh_syn_conductance": "0.19 nS"}

config_param_overrides = {
    'conn_number_override': {
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides, config_param_overrides=config_param_overrides)
