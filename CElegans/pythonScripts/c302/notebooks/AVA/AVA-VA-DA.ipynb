# %%
import os
import sys
os.chdir("../..") 

from runAndPlot import run_c302

# %matplotlib inline
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = (20.0, 15.0)

# %%
cells, cells_to_stimulate, params, muscles = run_c302('AVA_VA_DA','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVA")
# Out:
# ********************
#
#    Going to generate c302_C2_AVA_VA_DA and run for 4000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C
# Set default parameters for C2
# Opened file: /home/david.lung/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# Opened file: /home/david.lung/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# c302      >>>  Positioning muscle: MDR01 at (80,-270,80)
# c302      >>>  Positioning muscle: MDR02 at (80,-240,80)
# c302      >>>  Positioning muscle: MDR03 at (80,-210,80)
# c302      >>>  Positioning muscle: MDR04 at (80,-180,80)
# c302      >>>  Positioning muscle: MDR05 at (80,-150,80)
# c302      >>>  Positioning muscle: MDR06 at (80,-120,80)
# c302      >>>  Positioning muscle: MDR07 at (80,-90,80)
# c302      >>>  Positioning muscle: MDR08 at (80,-60,80)
# c302      >>>  Positioning muscle: MDR09 at (80,-30,80)
# ...

# %%
config_param_overrides = {
    'conn_number_override': {
        'DB1-AVBR_GJ': 15*0,
        'DB2-AVBL_GJ': 4*0,
        'DB2-AVBR_GJ': 3*0,
        'DB3-AVBL_GJ': 9*0,
        'DB3-AVBR_GJ': 2*0,
        'DB4-AVBL_GJ': 4*0,
        'DB4-AVBR_GJ': 5*0,
        'DB5-AVBL_GJ': 3*0,
        'DB5-AVBR_GJ': 4*0,
        'DB6-AVBL_GJ': 3*0,
        'DB6-AVBR_GJ': 4*0,
        'DB7-AVBL_GJ': 13*0,
        'DB7-AVBR_GJ': 3*0,
        
        'VB1-AVBL_GJ': 1*0,
        'VB2-AVBL_GJ': 14*0,
        'VB2-AVBR_GJ': 6*0,
        'VB3-AVBR_GJ': 7*0,
        'VB4-AVBL_GJ': 3*0,
        'VB4-AVBR_GJ': 5*0,
        'VB5-AVBL_GJ': 3*0,
        'VB5-AVBR_GJ': 3*0,
        'VB6-AVBL_GJ': 3*0,
        'VB6-AVBR_GJ': 4*0,
        'VB7-AVBL_GJ': 4*0,
        'VB7-AVBR_GJ': 3*0,
        'VB8-AVBL_GJ': 3*0,
        'VB8-AVBR_GJ': 4*0,
        'VB9-AVBL_GJ': 4*0,
        'VB9-AVBR_GJ': 3*0,
        'VB10-AVBL_GJ': 3*0,
        'VB10-AVBR_GJ': 4*0,
        'VB11-AVBL_GJ': 5*0,
        'VB11-AVBR_GJ': 6*0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB_DB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)
