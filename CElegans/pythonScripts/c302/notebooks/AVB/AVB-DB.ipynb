# %%
import os
import sys
os.chdir("../..") 

from runAndPlot import run_c302
# %matplotlib inline
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = (20.0, 15.0)
#plt.rcParams["font.size"] = "80"
#plt.rcParams['legend.fontsize'] = "80"

# %%
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB")

# %%
#param_overrides = {"neuron_to_muscle_exc_syn_conductance": "2.50 nS"}
param_overrides = {
    "DB1_to_MDL06_exc_syn_conductance": "0.4 nS",
    #"DB1_to_MDL06_exc_syn_vth": "10 mV",
    "DB1_to_MDL08_exc_syn_conductance": "0.40 nS",
    #"DB1_to_MDL08_exc_syn_vth": "10.5 mV",
    "DB1_to_MDL09_exc_syn_conductance": "0.16 nS",
    #"DB1_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL09_exc_syn_conductance": "0.10 nS",
    #"DB2_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL10_exc_syn_conductance": "0.255 nS",
    #"DB2_to_MDL10_exc_syn_vth": "11.5 mV",
    "DB2_to_MDL11_exc_syn_conductance": "0.2046 nS",
    #"DB2_to_MDL11_exc_syn_vth": "12 mV",
    "DB2_to_MDL12_exc_syn_conductance": "1.020 nS",
    #"DB2_to_MDL12_exc_syn_vth": "12.5 mV",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',1000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C2_AVB_DB_TUNE1 and run for 1000 on jNeuroML_NEURON
#
# ********************
# /home/david.lung/forks/CElegansNeuroML/CElegans/pythonScripts/c302
# Set default parameters for C
# Set default parameters for C2
# c302      >>>  Setting parameter DB1_to_MDL06_exc_syn_conductance = 0.4 nS
# c302      >>>  Setting parameter DB1_to_MDL08_exc_syn_conductance = 0.40 nS
# c302      >>>  Setting parameter DB2_to_MDL10_exc_syn_conductance = 0.255 nS
# c302      >>>  Setting parameter DB1_to_MDL09_exc_syn_conductance = 0.16 nS
# c302      >>>  Setting parameter DB2_to_MDL12_exc_syn_conductance = 1.020 nS
# c302      >>>  Setting parameter DB2_to_MDL11_exc_syn_conductance = 0.2046 nS
# c302      >>>  Setting parameter DB2_to_MDL09_exc_syn_conductance = 0.10 nS
# Opened file: /home/david.lung/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# ...

# %%
#param_overrides = {"neuron_to_muscle_exc_syn_conductance": "2.50 nS"}
param_overrides = {
    "AVBR_to_DB1_elec_syn_sigma": "0.7",
    "AVBR_to_DB1_elec_syn_mu": "-50",
    
    "AVBL_to_DB2_elec_syn_sigma": "0.65",
    "AVBL_to_DB2_elec_syn_mu": "-45",
    "AVBR_to_DB2_elec_syn_sigma": "0.65",
    "AVBR_to_DB2_elec_syn_mu": "-45",
    
    "AVBL_to_DB3_elec_syn_sigma": "0.6",
    "AVBL_to_DB3_elec_syn_mu": "-40",
    "AVBR_to_DB3_elec_syn_sigma": "0.6",
    "AVBR_to_DB3_elec_syn_mu": "-40",
    
    "AVBL_to_DB4_elec_syn_sigma": "0.55",
    "AVBL_to_DB4_elec_syn_mu": "-35",
    "AVBR_to_DB4_elec_syn_sigma": "0.55",
    "AVBR_to_DB4_elec_syn_mu": "-35",
    
    "AVBL_to_DB5_elec_syn_sigma": "0.5",
    "AVBL_to_DB5_elec_syn_mu": "-30",
    "AVBR_to_DB5_elec_syn_sigma": "0.5",
    "AVBR_to_DB5_elec_syn_mu": "-30",
    
    "AVBL_to_DB6_elec_syn_sigma": "0.45",
    "AVBL_to_DB6_elec_syn_mu": "-25",
    "AVBR_to_DB6_elec_syn_sigma": "0.45",
    "AVBR_to_DB6_elec_syn_mu": "-25",
    
    "AVBL_to_DB7_elec_syn_sigma": "0.4",
    "AVBL_to_DB7_elec_syn_mu": "-20",
    "AVBR_to_DB7_elec_syn_sigma": "0.4",
    "AVBR_to_DB7_elec_syn_mu": "-20",
    
    "DB1_to_MDL06_exc_syn_conductance": "0.52 nS",
    "DB1_to_MDL08_exc_syn_conductance": "0.47 nS",
    "DB1_to_MDL09_exc_syn_conductance": "0.13 nS",
    "DB2_to_MDL09_exc_syn_conductance": "0.10 nS",
    "DB2_to_MDL10_exc_syn_conductance": "0.240 nS",
    "DB2_to_MDL11_exc_syn_conductance": "0.2120 nS",
    "DB2_to_MDL12_exc_syn_conductance": "1.140 nS",
    
    "DB1_to_MDL06_exc_syn_sigma": "0.3",
    "DB1_to_MDL06_exc_syn_mu": "-50",
    
    "DB1_to_MDL08_exc_syn_sigma": "0.3",
    "DB1_to_MDL08_exc_syn_mu": "-40",
    
    "DB1_to_MDL09_exc_syn_sigma": "0.3",
    "DB1_to_MDL09_exc_syn_mu": "-35",
    
    "DB2_to_MDL09_exc_syn_sigma": "0.3",
    "DB2_to_MDL09_exc_syn_mu": "-35",
    
    "DB2_to_MDL10_exc_syn_sigma": "0.3",
    "DB2_to_MDL10_exc_syn_mu": "-30",
    
    "DB2_to_MDL11_exc_syn_sigma": "0.3",
    "DB2_to_MDL11_exc_syn_mu": "-25",
    
    "DB2_to_MDL12_exc_syn_sigma": "0.3",
    "DB2_to_MDL12_exc_syn_mu": "-20",
    
    "DB1_to_DB2_elec_syn_gbase": "0.00052 nS",
    "DB2_to_DB3_elec_syn_gbase": "0.00052 nS",
    "DB3_to_DB4_elec_syn_gbase": "0.00052 nS",
    "DB4_to_DB5_elec_syn_gbase": "0.00052 nS",
    "DB5_to_DB6_elec_syn_gbase": "0.00052 nS",
    "DB6_to_DB7_elec_syn_gbase": "0.00052 nS",
    
    "DB7_to_DB6_elec_syn_gbase": "0.00052 nS",
    "DB6_to_DB5_elec_syn_gbase": "0.00052 nS",
    "DB5_to_DB4_elec_syn_gbase": "0.00052 nS",
    "DB4_to_DB3_elec_syn_gbase": "0.00052 nS",
    "DB3_to_DB2_elec_syn_gbase": "0.00052 nS",
    "DB2_to_DB1_elec_syn_gbase": "0.00052 nS",
    
    "muscle_to_muscle_elec_syn_gbase": "0.00017 nS",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',1000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C2_AVB_DB and run for 1000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C
# Set default parameters for C2
# c302      >>>  Setting parameter DB1_to_MDL06_exc_syn_conductance = 0.52 nS
# c302      >>>  Setting parameter AVBR_to_DB2_elec_syn_mu = -45
# c302      >>>  Setting parameter AVBL_to_DB3_elec_syn_sigma = 0.6
# c302      >>>  Setting parameter DB1_to_MDL08_exc_syn_sigma = 0.3
# c302      >>>  Setting parameter DB1_to_MDL08_exc_syn_mu = -40
# c302      >>>  Setting parameter AVBR_to_DB7_elec_syn_sigma = 0.4
# c302      >>>  Setting parameter DB1_to_MDL06_exc_syn_mu = -50
# c302      >>>  Setting parameter DB3_to_DB4_elec_syn_gbase = 0.00000 nS
# c302      >>>  Setting parameter DB2_to_MDL10_exc_syn_conductance = 0.240 nS
# c302      >>>  Setting parameter DB6_to_DB5_elec_syn_gbase = 0.00000 nS
# c302      >>>  Setting parameter AVBL_to_DB7_elec_syn_sigma = 0.4
# ...

# %%
#param_overrides = {"neuron_to_muscle_exc_syn_conductance": "2.50 nS"}
param_overrides = {
    "DB1_to_MDL06_exc_syn_conductance": "0.4 nS",
    "DB1_to_MDL06_exc_syn_sigma": "0.5",
    "DB1_to_MDL06_exc_syn_mu": "-40",
    
    "DB1_to_MDL08_exc_syn_conductance": "0.60 nS",
    "DB1_to_MDL08_exc_syn_sigma": "0.4",
    "DB1_to_MDL08_exc_syn_mu": "-30",
    
    "DB1_to_MDL09_exc_syn_conductance": "0.12 nS",
    "DB1_to_MDL09_exc_syn_sigma": "0.35",
    "DB1_to_MDL09_exc_syn_mu": "-25",
    
    "DB2_to_MDL09_exc_syn_conductance": "0.10 nS",
    "DB2_to_MDL09_exc_syn_sigma": "0.35",
    "DB2_to_MDL09_exc_syn_mu": "-25",
    
    "DB2_to_MDL10_exc_syn_conductance": "0.205 nS",
    "DB2_to_MDL10_exc_syn_sigma": "0.30",
    "DB2_to_MDL10_exc_syn_mu": "-20",
    
    "DB2_to_MDL11_exc_syn_conductance": "0.1846 nS",
    "DB2_to_MDL11_exc_syn_sigma": "0.25",
    "DB2_to_MDL11_exc_syn_mu": "-15",
    
    "DB2_to_MDL12_exc_syn_conductance": "1.020 nS",
    "DB2_to_MDL12_exc_syn_sigma": "0.20",
    "DB2_to_MDL12_exc_syn_mu": "-10",
    
    
    
    "muscle_to_muscle_elec_syn_gbase": "0.00015 nS",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',1000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C2_AVB_DB_TUNE1 and run for 1000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C
# Set default parameters for C2
# c302      >>>  Setting parameter DB1_to_MDL06_exc_syn_conductance = 0.4 nS
# c302      >>>  Setting parameter DB2_to_MDL10_exc_syn_mu = -20
# c302      >>>  Setting parameter DB1_to_MDL08_exc_syn_sigma = 0.4
# c302      >>>  Setting parameter DB1_to_MDL08_exc_syn_mu = -30
# c302      >>>  Setting parameter DB1_to_MDL06_exc_syn_mu = -40
# c302      >>>  Setting parameter DB1_to_MDL08_exc_syn_conductance = 0.60 nS
# c302      >>>  Setting parameter DB2_to_MDL10_exc_syn_conductance = 0.205 nS
# c302      >>>  Setting parameter DB2_to_MDL11_exc_syn_mu = -15
# c302      >>>  Setting parameter neuron_to_neuron_elec_syn_gbase = 0 nS
# c302      >>>  Setting parameter DB2_to_MDL12_exc_syn_mu = -10
# c302      >>>  Setting parameter DB2_to_MDL12_exc_syn_sigma = 0.20
# ...

# %%
param_overrides = {
    "DB1_to_MDL06_exc_syn_conductance": "0.4 nS",
    "DB1_to_MDL06_exc_syn_vth": "10 mV",
    "DB1_to_MDL08_exc_syn_conductance": "0.40 nS",
    "DB1_to_MDL08_exc_syn_vth": "11 mV",
    "DB1_to_MDL09_exc_syn_conductance": "0.16 nS",
    "DB1_to_MDL09_exc_syn_vth": "11.5 mV",
    "DB2_to_MDL09_exc_syn_conductance": "0.10 nS",
    "DB2_to_MDL09_exc_syn_vth": "11.5 mV",
    "DB2_to_MDL10_exc_syn_conductance": "0.255 nS",
    "DB2_to_MDL10_exc_syn_vth": "12 mV",
    "DB2_to_MDL11_exc_syn_conductance": "0.2146 nS",
    "DB2_to_MDL11_exc_syn_vth": "12.5 mV",
    "DB2_to_MDL12_exc_syn_conductance": "1.600 nS",
    "DB2_to_MDL12_exc_syn_vth": "13 mV",
    "DB2_to_MDL12_exc_syn_delta": "4.5 mV",
    
    "muscle_to_muscle_elec_syn_gbase": "0 nS",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',3000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)

# %%
param_overrides = {
    "DB1_to_MDL06_exc_syn_conductance": "0.4 nS",
    "DB1_to_MDL06_exc_syn_vth": "10 mV",
    "DB1_to_MDL08_exc_syn_conductance": "0.40 nS",
    "DB1_to_MDL08_exc_syn_vth": "10.5 mV",
    "DB1_to_MDL09_exc_syn_conductance": "0.16 nS",
    "DB1_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL09_exc_syn_conductance": "0.10 nS",
    "DB2_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL10_exc_syn_conductance": "0.255 nS",
    "DB2_to_MDL10_exc_syn_vth": "11.5 mV",
    "DB2_to_MDL11_exc_syn_conductance": "0.2146 nS",
    "DB2_to_MDL11_exc_syn_vth": "12 mV",
    "DB2_to_MDL12_exc_syn_conductance": "1.500 nS",
    "DB2_to_MDL12_exc_syn_vth": "12.5 mV",
    "DB2_to_MDL12_exc_syn_delta": "4.5 mV",
    
    "muscle_to_muscle_elec_syn_gbase": "0.00025 nS",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',6000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)

# %%
#param_overrides = {"neuron_to_muscle_exc_syn_conductance": "2.50 nS"}
param_overrides = {
    "DB1_to_MDL06_exc_syn_conductance": "0.25 nS",
    #"DB1_to_MDL06_exc_syn_vth": "10 mV",
    "DB1_to_MDL08_exc_syn_conductance": "0.25 nS",
    #"DB1_to_MDL08_exc_syn_vth": "10.5 mV",
    "DB1_to_MDL09_exc_syn_conductance": "0.10 nS",
    #"DB1_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL09_exc_syn_conductance": "0.064 nS",
    #"DB2_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL10_exc_syn_conductance": "0.158 nS",
    #"DB2_to_MDL10_exc_syn_vth": "11.5 mV",
    "DB2_to_MDL11_exc_syn_conductance": "0.1250 nS",
    #"DB2_to_MDL11_exc_syn_vth": "12 mV",
    "DB2_to_MDL12_exc_syn_conductance": "0.625 nS",
    #"DB2_to_MDL12_exc_syn_vth": "12.5 mV",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)

# %%
#param_overrides = {"neuron_to_muscle_exc_syn_conductance": "2.50 nS"}
param_overrides = {
    "DB1_to_MDL06_exc_syn_conductance": "0.25 nS",
    "DB1_to_MDL06_exc_syn_vth": "10 mV",
    "DB1_to_MDL08_exc_syn_conductance": "0.25 nS",
    "DB1_to_MDL08_exc_syn_vth": "10.5 mV",
    "DB1_to_MDL09_exc_syn_conductance": "0.10 nS",
    "DB1_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL09_exc_syn_conductance": "0.064 nS",
    "DB2_to_MDL09_exc_syn_vth": "11 mV",
    "DB2_to_MDL10_exc_syn_conductance": "0.188 nS",
    "DB2_to_MDL10_exc_syn_vth": "11.5 mV",
    "DB2_to_MDL11_exc_syn_conductance": "0.1250 nS",
    "DB2_to_MDL11_exc_syn_vth": "12 mV",
    "DB2_to_MDL12_exc_syn_conductance": "0.625 nS",
    "DB2_to_MDL12_exc_syn_vth": "12.5 mV",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)

# %%
#param_overrides = {"neuron_to_muscle_exc_syn_conductance": "2.50 nS"}
param_overrides = {
    "DB1_to_MDL06_exc_syn_conductance": "0.2 nS",
    "DB1_to_MDL06_exc_syn_vth": "10 mV",
    "DB1_to_MDL08_exc_syn_conductance": "0.30 nS",
    "DB1_to_MDL08_exc_syn_vth": "12 mV",
    "DB1_to_MDL09_exc_syn_conductance": "0.16 nS",
    "DB1_to_MDL09_exc_syn_vth": "13 mV",
    "DB2_to_MDL09_exc_syn_conductance": "0.10 nS",
    "DB2_to_MDL09_exc_syn_vth": "13 mV",
    "DB2_to_MDL10_exc_syn_conductance": "0.255 nS",
    "DB2_to_MDL10_exc_syn_vth": "14 mV",
    "DB2_to_MDL11_exc_syn_conductance": "0.2046 nS",
    "DB2_to_MDL11_exc_syn_vth": "15 mV",
    "DB2_to_MDL12_exc_syn_conductance": "1.220 nS",
    "DB2_to_MDL12_exc_syn_vth": "16 mV",
    
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB_TUNE1','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", param_overrides=param_overrides)

# %%
config_param_overrides = {
    "conn_number_override": {
        "DB1-DB2_GJ":0,
        "DB2-DB1_GJ":0,
        "DB2-DB3_GJ":0,
        "DB3-DB2_GJ":0,
        "DB3-DB4_GJ":0,
        "DB4-DB3_GJ":0,
        "DB4-DB5_GJ":0,
        "DB5-DB4_GJ":0,
        "DB5-DB6_GJ":0,
        "DB6-DB5_GJ":0,
        "DB6-DB7_GJ":0,
        "DB7-DB6_GJ":0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
config_param_overrides = {
    "conn_number_override": {
        "DB1-DB2_GJ":0,
        "DB2-DB1_GJ":0,
        "DB2-DB3_GJ":0,
        "DB3-DB2_GJ":0,
        "DB3-DB4_GJ":0,
        "DB4-DB3_GJ":0,
        "DB4-DB5_GJ":0,
        "DB5-DB4_GJ":0,
        "DB5-DB6_GJ":0,
        "DB6-DB5_GJ":0,
        "DB6-DB7_GJ":0,
        "DB7-DB6_GJ":0,
        
        "AVBL-AVBR":0,
        "AVBR-AVBL":0,
        "AVBR-DB4":0,
        "AVBL-AVBR_GJ":0,
        "AVBR-AVBL_GJ":0,
        
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
config_param_overrides = {
    "conn_number_override": {
        "DB1-DB2_GJ":0,
        "DB2-DB1_GJ":0,
        "DB2-DB3_GJ":0,
        "DB3-DB2_GJ":0,
        "DB3-DB4_GJ":0,
        "DB4-DB3_GJ":0,
        "DB4-DB5_GJ":0,
        "DB5-DB4_GJ":0,
        "DB5-DB6_GJ":0,
        "DB6-DB5_GJ":0,
        "DB6-DB7_GJ":0,
        "DB7-DB6_GJ":0,
        
        "AVBL-AVBR":0,
        "AVBR-AVBL":0,
        "AVBR-DB4":0,
        "AVBL-AVBR_GJ":0,
        "AVBR-AVBL_GJ":0,
        
        "DB1-AVBR_GJ":0,
        "DB2-AVBL_GJ":0,
        "DB2-AVBR_GJ":0,
        "DB3-AVBL_GJ":0,
        "DB3-AVBR_GJ":0,
        "DB4-AVBL_GJ":0,
        "DB4-AVBR_GJ":0,
        "DB5-AVBL_GJ":0,
        "DB5-AVBR_GJ":0,
        "DB6-AVBL_GJ":0,
        "DB6-AVBR_GJ":0,
        "DB7-AVBL_GJ":0,
        "DB7-AVBR_GJ":0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
config_param_overrides = {
    "conn_number_override": {
        "DB1-DB2_GJ":0,
        "DB2-DB1_GJ":0,
        "DB2-DB3_GJ":0,
        "DB3-DB2_GJ":0,
        "DB3-DB4_GJ":0,
        "DB4-DB3_GJ":0,
        "DB4-DB5_GJ":0,
        "DB5-DB4_GJ":0,
        "DB5-DB6_GJ":0,
        "DB6-DB5_GJ":0,
        "DB6-DB7_GJ":0,
        "DB7-DB6_GJ":0,
        
        "AVBL-AVBR":0,
        "AVBR-AVBL":0,
        "AVBR-DB4":0,
        "AVBL-AVBR_GJ":0,
        "AVBR-AVBL_GJ":0,
        
        "DB1-AVBR_GJ":0,
        "DB2-AVBL_GJ":0,
        "DB2-AVBR_GJ":0,
        "DB3-AVBL_GJ":0,
        "DB3-AVBR_GJ":0,
        "DB4-AVBL_GJ":0,
        "DB4-AVBR_GJ":0,
        "DB5-AVBL_GJ":0,
        "DB5-AVBR_GJ":0,
        "DB6-AVBL_GJ":0,
        "DB6-AVBR_GJ":0,
        "DB7-AVBL_GJ":0,
        "DB7-AVBR_GJ":0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
config_param_overrides = {
    "conn_number_override": {
        
        #"AVBL-AVBR":0,
        #"AVBR-AVBL":0,
        #"AVBR-DB4":0,
        #"AVBL-AVBR_GJ":0,
        #"AVBR-AVBL_GJ":0,
        
        "DB1-AVBR_GJ":0,
        "DB2-AVBL_GJ":0,
        "DB2-AVBR_GJ":0,
        "DB3-AVBL_GJ":0,
        "DB3-AVBR_GJ":0,
        "DB4-AVBL_GJ":0,
        "DB4-AVBR_GJ":0,
        "DB5-AVBL_GJ":0,
        "DB5-AVBR_GJ":0,
        "DB6-AVBL_GJ":0,
        "DB6-AVBR_GJ":0,
        "DB7-AVBL_GJ":0,
        "DB7-AVBR_GJ":0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
config_param_overrides = {
    "conn_number_override": {
        "DB1-DB2_GJ":0,
        "DB2-DB1_GJ":0,
        "DB2-DB3_GJ":0,
        "DB3-DB2_GJ":0,
        "DB3-DB4_GJ":0,
        "DB4-DB3_GJ":0,
        "DB4-DB5_GJ":0,
        "DB5-DB4_GJ":0,
        "DB5-DB6_GJ":0,
        "DB6-DB5_GJ":0,
        "DB6-DB7_GJ":0,
        "DB7-DB6_GJ":0,
        
        "AVBL-AVBR":0,
        "AVBR-AVBL":0,
        "AVBL-AVBR_GJ":0,
        "AVBR-AVBL_GJ":0,
        
        "DB1-AVBR_GJ":0,
        "DB2-AVBL_GJ":0,
        "DB2-AVBR_GJ":0,
        "DB3-AVBL_GJ":0,
        "DB3-AVBR_GJ":0,
        "DB4-AVBL_GJ":0,
        "DB4-AVBR_GJ":0,
        "DB5-AVBL_GJ":0,
        "DB5-AVBR_GJ":0,
        "DB6-AVBL_GJ":0,
        "DB6-AVBR_GJ":0,
        "DB7-AVBL_GJ":0,
        "DB7-AVBR_GJ":0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
config_param_overrides = {
    "conn_number_override": {
        "DB1-DB2_GJ":0,
        "DB2-DB1_GJ":0,
        "DB2-DB3_GJ":0,
        "DB3-DB2_GJ":0,
        "DB3-DB4_GJ":0,
        "DB4-DB3_GJ":0,
        "DB4-DB5_GJ":0,
        "DB5-DB4_GJ":0,
        "DB5-DB6_GJ":0,
        "DB6-DB5_GJ":0,
        "DB6-DB7_GJ":0,
        "DB7-DB6_GJ":0,
        
        "DB1-AVBR_GJ":0,
        "DB2-AVBL_GJ":0,
        "DB2-AVBR_GJ":0,
        "DB3-AVBL_GJ":0,
        "DB3-AVBR_GJ":0,
        "DB4-AVBL_GJ":0,
        "DB4-AVBR_GJ":0,
        "DB5-AVBL_GJ":0,
        "DB5-AVBR_GJ":0,
        "DB6-AVBL_GJ":0,
        "DB6-AVBR_GJ":0,
        "DB7-AVBL_GJ":0,
        "DB7-AVBR_GJ":0,
    }
}

cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB", config_param_overrides=config_param_overrides)

# %%
cells, cells_to_stimulate, params, muscles = run_c302('AVB_DB','C2','',2000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB")
