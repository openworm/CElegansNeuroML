# %%
import os
import sys
os.chdir("../..")

# %%
# %matplotlib inline
from runAndPlot import run_c302
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = (20.0, 20.0)
cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB_DB_VD_DD_AS','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", config_package="notebooks.configs.AVB")
# Out:
# ********************
#
#    Going to generate c302_C2_AVB_VB_DB_VD_DD_AS and run for 4000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C
# Set default parameters for C2
# Opened file: /home/developer/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# Opened file: /home/developer/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# c302      >>>  Positioning muscle: MDR01 at (80,-270,80)
# c302      >>>  Positioning muscle: MDR02 at (80,-240,80)
# c302      >>>  Positioning muscle: MDR03 at (80,-210,80)
# c302      >>>  Positioning muscle: MDR04 at (80,-180,80)
# c302      >>>  Positioning muscle: MDR05 at (80,-150,80)
# c302      >>>  Positioning muscle: MDR06 at (80,-120,80)
# c302      >>>  Positioning muscle: MDR07 at (80,-90,80)
# c302      >>>  Positioning muscle: MDR08 at (80,-60,80)
# c302      >>>  Positioning muscle: MDR09 at (80,-30,80)
# ...

# %%
param_overrides = {
    'neuron_to_neuron_elec_syn_gbase': '0.001252 nS',
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB_DB_VD_DD_AS','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", param_overrides=param_overrides, config_package="notebooks.configs.AVB")
# Out:
# ********************
#
#    Going to generate c302_C2_AVB_VB_DB_VD_DD_AS and run for 4000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C
# Set default parameters for C2
# c302      >>>  Setting parameter neuron_to_neuron_elec_syn_gbase = 0.001252 nS
# Opened file: /home/developer/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# Opened file: /home/developer/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# c302      >>>  Positioning muscle: MDR01 at (80,-270,80)
# c302      >>>  Positioning muscle: MDR02 at (80,-240,80)
# c302      >>>  Positioning muscle: MDR03 at (80,-210,80)
# c302      >>>  Positioning muscle: MDR04 at (80,-180,80)
# c302      >>>  Positioning muscle: MDR05 at (80,-150,80)
# c302      >>>  Positioning muscle: MDR06 at (80,-120,80)
# c302      >>>  Positioning muscle: MDR07 at (80,-90,80)
# c302      >>>  Positioning muscle: MDR08 at (80,-60,80)
# ...

# %%
param_overrides = {
    'neuron_to_muscle_inh_syn_conductance': '0.07 nS'
}
cells, cells_to_stimulate, params, muscles = run_c302('AVB_VB_DB_VD_DD_AS','C2','',4000,0.05,'jNeuroML_NEURON',verbose=False, plot_ca=False, data_reader="UpdatedSpreadsheetDataReader", param_overrides=param_overrides, config_package="notebooks.configs.AVB")
# Out:
# ********************
#
#    Going to generate c302_C2_AVB_VB_DB_VD_DD_AS and run for 4000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C
# Set default parameters for C2
# c302      >>>  Setting parameter neuron_to_muscle_inh_syn_conductance = 0.07 nS
# Opened file: /home/developer/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# Opened file: /home/developer/forks/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# c302      >>>  Positioning muscle: MDR01 at (80,-270,80)
# c302      >>>  Positioning muscle: MDR02 at (80,-240,80)
# c302      >>>  Positioning muscle: MDR03 at (80,-210,80)
# c302      >>>  Positioning muscle: MDR04 at (80,-180,80)
# c302      >>>  Positioning muscle: MDR05 at (80,-150,80)
# c302      >>>  Positioning muscle: MDR06 at (80,-120,80)
# c302      >>>  Positioning muscle: MDR07 at (80,-90,80)
# c302      >>>  Positioning muscle: MDR08 at (80,-60,80)
# ...
