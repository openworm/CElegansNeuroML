# %%
import os
import sys
os.chdir("..")

# %% [markdown]
# ## Run IClamp with parameter set C0 with standard parameters

# %%
from runAndPlot import run_c302

# %matplotlib inline
cells, cells_to_stimulate, params, muscles = run_c302('IClamp','C0','',1000,0.05,'jNeuroML',verbose=False,plot_ca=False)
# Out:
# ********************
#
#    Going to generate c302_C0_IClamp and run for 1000 on jNeuroML
#
# ********************
# Set default parameters for C0
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Positioning muscle: MDR01 at (80,-270,80)
# c302      >>>  Writing generated network to: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_IClamp.nml
# (Re)written network file to: examples/c302_C0_IClamp.nml
# c302      >>>  Finished simulation of LEMS_c302_C0_IClamp.xml and have reloaded results
# c302      >>>  Reloaded data: ['MDR01/0/GenericMuscleCell/caConc', 'ADAL/0/GenericNeuronCell/caConc', 'PVCL/0/GenericNeuronCell/v', 'MDR01/0/GenericMuscleCell/v', 't', 'PVCL/0/GenericNeuronCell/caConc', 'ADAL/0/GenericNeuronCell/v']
# c302      >>>  All cells: ['PVCL', 'ADAL']
# c302      >>>  Plotting neuron voltages
# c302      >>>  Generating plots for: Membrane potentials of 2 neuron(s) (IClamp C0)
# pyNeuroML >>> Generating plot: Membrane potentials of 2 neuron(s) (IClamp C0)
# c302      >>>  Plotting muscle voltages
# c302      >>>  Generating plots for: Membrane potentials of 1 muscle(s) (IClamp C0)
# pyNeuroML >>> Generating plot: Membrane potentials of 1 muscle(s) (IClamp C0)
# /usr/lib/python2.7/dist-packages/simplejson/encoder.py:275: DeprecationWarning: Interpreting naive datetime as local 2017-04-04 17:20:49.073481. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# ## List current parameters

# %%
print params.bioparameter_info("  ")
# Out:
#   Known BioParameters:
#     BioParameter: cell_diameter = 5 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_length = 20 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_specific_capacitance = 1 uF_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_specific_capacitance = 5 uF_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: initial_memb_pot = -50 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_spike_thresh = -20 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_spike_thresh = -20 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_leak_cond_density = 0.002 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_leak_cond_density = 0.1 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_k_slow_cond_density = .22 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_k_slow_cond_density = 0.1 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_ca_simple_cond_density = .15 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_ca_simple_cond_density = .2 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: leak_erev = -50 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: k_slow_erev = -93 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: ca_simple_erev = 60 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: ca_conc_decay_time = 200 ms (SRC: BlindGuess, certainty 0.1)
#     BioParameter: ca_conc_rho = 0.0002 mol_per_m_per_A_per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_neuron_exc_syn_conductance = 6 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_muscle_exc_syn_conductance = 3 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_ar = 1 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_ad = 50 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_beta = 0.125 per_mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_vth = -30 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_erev = 0 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_neuron_inh_syn_conductance = 44 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_muscle_inh_syn_conductance = 0.3 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_ar = 1 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_ad = 50 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_beta = 0.125 per_mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_vth = -30 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_erev = -80 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_neuron_elec_syn_gbase = 0.000 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_muscle_elec_syn_gbase = 0.0001 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: unphysiological_offset_current = 4 pA (SRC: KnownError, certainty 0)
#     BioParameter: unphysiological_offset_current_del = 0 ms (SRC: KnownError, certainty 0)
#     BioParameter: unphysiological_offset_current_dur = 2000 ms (SRC: KnownError, certainty 0)
# /usr/lib/python2.7/dist-packages/simplejson/encoder.py:275: DeprecationWarning: Interpreting naive datetime as local 2017-04-04 17:21:23.540093. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# ## Change some parameters and run again (muscle will spike...)

# %%
param_overrides = {"muscle_k_slow_cond_density": ".22 mS_per_cm2",
                   "muscle_ca_simple_cond_density": ".15 mS_per_cm2",
                   "muscle_leak_cond_density": "0.002 mS_per_cm2",
                  "k_slow_erev": "-93 mV",
                  "ca_simple_erev": "60 mV"}

run_c302('IClamp','C0','',1000,0.05,'jNeuroML',verbose=False,plot_ca=False,param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C0_IClamp and run for 1000 on jNeuroML
#
# ********************
# Set default parameters for C0
# c302      >>>  Setting parameter muscle_leak_cond_density = 0.002 mS_per_cm2
# c302      >>>  Setting parameter k_slow_erev = -93 mV
# c302      >>>  Setting parameter muscle_ca_simple_cond_density = .15 mS_per_cm2
# c302      >>>  Setting parameter ca_simple_erev = 60 mV
# c302      >>>  Setting parameter muscle_k_slow_cond_density = .22 mS_per_cm2
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Positioning muscle: MDR01 at (80,-270,80)
# c302      >>>  Writing generated network to: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_IClamp.nml
# (Re)written network file to: examples/c302_C0_IClamp.nml
# c302      >>>  Finished simulation of LEMS_c302_C0_IClamp.xml and have reloaded results
# c302      >>>  Reloaded data: ['MDR01/0/GenericMuscleCell/caConc', 'ADAL/0/GenericNeuronCell/caConc', 'PVCL/0/GenericNeuronCell/v', 'MDR01/0/GenericMuscleCell/v', 't', 'PVCL/0/GenericNeuronCell/caConc', 'ADAL/0/GenericNeuronCell/v']
# c302      >>>  All cells: ['PVCL', 'ADAL']
# c302      >>>  Plotting neuron voltages
# c302      >>>  Generating plots for: Membrane potentials of 2 neuron(s) (IClamp C0)
# pyNeuroML >>> Generating plot: Membrane potentials of 2 neuron(s) (IClamp C0)
# c302      >>>  Plotting muscle voltages
# c302      >>>  Generating plots for: Membrane potentials of 1 muscle(s) (IClamp C0)
# pyNeuroML >>> Generating plot: Membrane potentials of 1 muscle(s) (IClamp C0)
# (['ADAL', 'PVCL'],
#  ['ADAL', 'PVCL', 'MDR01'],
#  <parameters_C0.ParameterisedModel at 0x7f948a335810>,
#  ['MDR01'])
# /usr/lib/python2.7/dist-packages/simplejson/encoder.py:275: DeprecationWarning: Interpreting naive datetime as local 2017-04-04 17:21:34.913218. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
