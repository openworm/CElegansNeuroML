# %%
import os
import sys
os.chdir("..")

# %% [markdown]
# ## Run IClamp with parameter set C0 with standard parameters

# %%
from runAndPlot import run_c302

# %matplotlib inline
cells, cells_to_stimulate, params, muscles = run_c302('IClamp','C0','',1000,0.05,'jNeuroML',verbose=False,plot_ca=False)
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ********************
#
#    Going to generate c302_C0_IClamp and run for 1000 on jNeuroML
#
# ********************
# Set default parameters for C0
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Writing generated network to: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_IClamp.nml
# (Re)written network file to: examples/c302_C0_IClamp.nml
# ...

# %% [markdown]
# ## List current parameters

# %%
print params.bioparameter_info("  ")
# Out:
#   Known BioParameters:
#     BioParameter: cell_diameter = 5 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_length = 20 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_specific_capacitance = .6860 uF_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_specific_capacitance = 5 uF_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: initial_memb_pot = -50 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_spike_thresh = -20 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_spike_thresh = -20 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_leak_cond_density = 0.00105 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_leak_cond_density = 0.1 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_k_slow_cond_density = 0.24491 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_k_slow_cond_density = 0.1 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
# ...

# %% [markdown]
# ## Change some parameters and run again (muscle will spike...)

# %%
param_overrides = {"muscle_k_slow_cond_density": "0.22 mS_per_cm2",
                   "muscle_ca_simple_cond_density": "0.15 mS_per_cm2",
                   "muscle_leak_cond_density": "0.005 mS_per_cm2",
                   "ca_conc_decay_time": "50 ms",
                  "k_slow_erev": "-93 mV",
                  "ca_simple_erev": "60 mV"}

run_c302('IClamp','C0','',1000,0.05,'jNeuroML',verbose=False,plot_ca=True,param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C0_IClamp and run for 1000 on jNeuroML
#
# ********************
# Set default parameters for C0
# c302      >>>  Setting parameter muscle_ca_simple_cond_density = 0.15 mS_per_cm2
# c302      >>>  Setting parameter k_slow_erev = -93 mV
# c302      >>>  Setting parameter muscle_leak_cond_density = 0.005 mS_per_cm2
# c302      >>>  Setting parameter muscle_k_slow_cond_density = 0.22 mS_per_cm2
# c302      >>>  Setting parameter ca_conc_decay_time = 50 ms
# c302      >>>  Setting parameter ca_simple_erev = 60 mV
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# ...
