# %%
import os
import sys
os.chdir("..")

# %% [markdown]
# ## Run Oscillator with parameter set C0 with standard parameters

# %%
from runAndPlot import run_c302

# %matplotlib inline
cells, cells_to_stimulate, params, muscles = run_c302('Oscillator',
                                                      'C0',
                                                      '',
                                                      1000,0.05,
                                                      'jNeuroML',
                                                      verbose=False,
                                                      plot_ca=False)
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ********************
#
#    Going to generate c302_C0_Oscillator and run for 1000 on jNeuroML
#
# ********************
# Set default parameters for C0
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Writing generated network to: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_Oscillator.nml
# c302      >>>  Finished simulation of LEMS_c302_C0_Oscillator.xml and have reloaded results
# c302      >>>  Reloaded data: ['DA3/0/GenericNeuronCell/v', 'VB3/0/GenericNeuronCell/caConc', 'PLMR/0/GenericNeuronCell/v', 'DB3/0/GenericNeuronCell/caConc', 'DA3/0/GenericNeuronCell/caConc', 'VB2/0/GenericNeuronCell/caConc', 'DD2/0/GenericNeuronCell/v', 'VD3/0/GenericNeuronCell/v', 'DA2/0/GenericNeuronCell/v', 'VA2/0/GenericNeuronCell/caConc', 'DD2/0/GenericNeuronCell/caConc', 'AVAL/0/GenericNeuronCell/caConc', 'DD3/0/GenericNeuronCell/v', 'VA3/0/GenericNeuronCell/caConc', 'PLML/0/GenericNeuronCell/v', 'VA2/0/GenericNeuronCell/v', 'DB2/0/GenericNeuronCell/caConc', 'VD2/0/GenericNeuronCell/v', 'DB2/0/GenericNeuronCell/v', 'DD3/0/GenericNeuronCell/caConc', 'PLML/0/GenericNeuronCell/caConc', 'AVAR/0/GenericNeuronCell/caConc', 'DA2/0/GenericNeuronCell/caConc', 'AVAL/0/GenericNeuronCell/v', 'AVAR/0/GenericNeuronCell/v', 'DB3/0/GenericNeuronCell/v', 'VA3/0/GenericNeuronCell/v', 'VB3/0/GenericNeuronCell/v', 'VB2/0/GenericNeuronCell/v', 'VD3/0/GenericNeuronCell/caConc', 'VD2/0/GenericNeuronCell/caConc', 't', 'PLMR/0/GenericNeuronCell/caConc']
# c302      >>>  All cells: ['VD3', 'VD2', 'VB3', 'VB2', 'VA3', 'VA2', 'PLMR', 'PLML', 'DD3', 'DD2', 'DB3', 'DB2', 'DA3', 'DA2', 'AVAR', 'AVAL']
# c302      >>>  Plotting neuron voltages
# c302      >>>  Generating plots for: Membrane potentials of 16 neuron(s) (Oscillator C0)
# pyNeuroML >>> Generating plot: Membrane potentials of 16 neuron(s) (Oscillator C0)
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-04 20:44:17.583462. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# ## List current parameters

# %%
print params.bioparameter_info("  ")
# Out:
#   Known BioParameters:
#     BioParameter: cell_diameter = 5 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_length = 20 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_specific_capacitance = 1 uF_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_specific_capacitance = 5 uF_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: initial_memb_pot = -50 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_spike_thresh = -20 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_spike_thresh = -20 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_leak_cond_density = 0.002 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_leak_cond_density = 0.1 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_k_slow_cond_density = .22 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_k_slow_cond_density = 0.1 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: muscle_ca_simple_cond_density = .15 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_ca_simple_cond_density = .2 mS_per_cm2 (SRC: BlindGuess, certainty 0.1)
#     BioParameter: leak_erev = -50 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: k_slow_erev = -93 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: ca_simple_erev = 60 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: ca_conc_decay_time = 200 ms (SRC: BlindGuess, certainty 0.1)
#     BioParameter: ca_conc_rho = 0.0002 mol_per_m_per_A_per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_neuron_exc_syn_conductance = 6 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_muscle_exc_syn_conductance = 12 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_ar = 1 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_ad = 50 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_beta = 0.125 per_mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_vth = -30 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: exc_syn_erev = 0 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_neuron_inh_syn_conductance = 44 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_muscle_inh_syn_conductance = 0.3 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_ar = 1 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_ad = 50 per_s (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_beta = 0.125 per_mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_vth = -30 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: inh_syn_erev = -90 mV (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_neuron_elec_syn_gbase = 0.000 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: neuron_to_muscle_elec_syn_gbase = 0.0001 nS (SRC: BlindGuess, certainty 0.1)
#     BioParameter: unphysiological_offset_current = 2pA (SRC: Testing Osc, certainty 0)
#     BioParameter: unphysiological_offset_current_del = 10 ms (SRC: Testing Osc, certainty 0)
#     BioParameter: unphysiological_offset_current_dur = 2500 ms (SRC: Testing Osc, certainty 0)
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-04 20:45:39.868080. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %% [markdown]
# ## Change some parameters and run again

# %%
param_overrides = {"neuron_to_neuron_exc_syn_conductance": "5 nS",
                   "neuron_to_neuron_inh_syn_conductance": "50 nS",
                   "neuron_to_neuron_elec_syn_gbase": "0.01 nS",
                  "inh_syn_ar":".5 per_s",
                  "exc_syn_ar":".5 per_s"}

run_c302('Oscillator','C0','',1000,0.05,'jNeuroML',verbose=False,plot_ca=False,param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C0_Oscillator and run for 1000 on jNeuroML
#
# ********************
# Set default parameters for C0
# c302      >>>  Setting parameter inh_syn_ar = .5 per_s
# c302      >>>  Setting parameter exc_syn_ar = .5 per_s
# c302      >>>  Setting parameter neuron_to_neuron_elec_syn_gbase = 0.01 nS
# c302      >>>  Setting parameter neuron_to_neuron_inh_syn_conductance = 50 nS
# c302      >>>  Setting parameter neuron_to_neuron_exc_syn_conductance = 5 nS
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Writing generated network to: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_Oscillator.nml
# c302      >>>  Finished simulation of LEMS_c302_C0_Oscillator.xml and have reloaded results
# c302      >>>  Reloaded data: ['DA3/0/GenericNeuronCell/v', 'VB3/0/GenericNeuronCell/caConc', 'PLMR/0/GenericNeuronCell/v', 'DB3/0/GenericNeuronCell/caConc', 'DA3/0/GenericNeuronCell/caConc', 'VB2/0/GenericNeuronCell/caConc', 'DD2/0/GenericNeuronCell/v', 'VD3/0/GenericNeuronCell/v', 'DA2/0/GenericNeuronCell/v', 'VA2/0/GenericNeuronCell/caConc', 'DD2/0/GenericNeuronCell/caConc', 'AVAL/0/GenericNeuronCell/caConc', 'DD3/0/GenericNeuronCell/v', 'VA3/0/GenericNeuronCell/caConc', 'PLML/0/GenericNeuronCell/v', 'VA2/0/GenericNeuronCell/v', 'DB2/0/GenericNeuronCell/caConc', 'VD2/0/GenericNeuronCell/v', 'DB2/0/GenericNeuronCell/v', 'DD3/0/GenericNeuronCell/caConc', 'PLML/0/GenericNeuronCell/caConc', 'AVAR/0/GenericNeuronCell/caConc', 'DA2/0/GenericNeuronCell/caConc', 'AVAL/0/GenericNeuronCell/v', 'AVAR/0/GenericNeuronCell/v', 'DB3/0/GenericNeuronCell/v', 'VA3/0/GenericNeuronCell/v', 'VB3/0/GenericNeuronCell/v', 'VB2/0/GenericNeuronCell/v', 'VD3/0/GenericNeuronCell/caConc', 'VD2/0/GenericNeuronCell/caConc', 't', 'PLMR/0/GenericNeuronCell/caConc']
# c302      >>>  All cells: ['VD3', 'VD2', 'VB3', 'VB2', 'VA3', 'VA2', 'PLMR', 'PLML', 'DD3', 'DD2', 'DB3', 'DB2', 'DA3', 'DA2', 'AVAR', 'AVAL']
# c302      >>>  Plotting neuron voltages
# c302      >>>  Generating plots for: Membrane potentials of 16 neuron(s) (Oscillator C0)
# pyNeuroML >>> Generating plot: Membrane potentials of 16 neuron(s) (Oscillator C0)
# (['DB2',
#   'VB2',
#   'DD2',
#   'VD2',
#   'DB3',
#   'VB3',
#   'DD3',
#   'VD3',
#   'DA2',
#   'VA2',
#   'DA3',
#   'VA3',
#   'PLML',
#   'PLMR',
#   'AVAL',
#   'AVAR'],
#  ['PLML', 'PLMR'],
#  <parameters_C0.ParameterisedModel at 0x10fd43dd0>,
#  [])
# /usr/local/Cellar/python/2.7.13/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-04-04 21:06:23.126885. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
