# %%
import os
import sys
os.chdir("..")

# %% [markdown]
# ## Run Muscles config with parameter set C0 with standard parameters

# %%
from runAndPlot import run_c302

# %matplotlib inline
cells, cells_to_stimulate, params, muscles = run_c302('Muscles',
                                                      'C0',
                                                      '',
                                                      1000,0.05,
                                                      'jNeuroML_NEURON',
                                                      verbose=False,
                                                      plot_ca=False)
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ********************
#
#    Going to generate c302_C0_Muscles and run for 1000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C0
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Writing generated network to: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_Muscles.nml
# c302      >>>  Finished simulation of LEMS_c302_C0_Muscles.xml and have reloaded results
# ...

# %%
param_overrides = {"exc_syn_vth": "-25 mV",
                   "neuron_to_neuron_exc_syn_conductance": "25 nS",
                   "neuron_to_muscle_exc_syn_conductance": "25 nS",
                   "neuron_to_neuron_inh_syn_conductance": "60 nS",
                   "neuron_to_neuron_elec_syn_gbase": "0.05 nS",
                   "unphysiological_offset_current":"5pA",
                   "ca_conc_decay_time": "20 ms"}

run_c302('Muscles','C0','',1000,0.05,'jNeuroML_NEURON',verbose=False,plot_ca=True,param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C0_Muscles and run for 1000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C0
# c302      >>>  Setting parameter ca_conc_decay_time = 20 ms
# c302      >>>  Setting parameter neuron_to_muscle_exc_syn_conductance = 25 nS
# c302      >>>  Setting parameter exc_syn_vth = -25 mV
# c302      >>>  Setting parameter neuron_to_neuron_exc_syn_conductance = 25 nS
# c302      >>>  Setting parameter unphysiological_offset_current = 5pA
# c302      >>>  Setting parameter neuron_to_neuron_elec_syn_gbase = 0.05 nS
# c302      >>>  Setting parameter neuron_to_neuron_inh_syn_conductance = 60 nS
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /Users/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# ...
