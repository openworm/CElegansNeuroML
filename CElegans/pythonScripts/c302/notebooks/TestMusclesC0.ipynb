# %%
import os
import sys
os.chdir("..")

# %% [markdown]
# ## Run Oscillator with parameter set C0 with standard parameters

# %%
from runAndPlot import run_c302

# %matplotlib inline
cells, cells_to_stimulate, params, muscles = run_c302('Muscles',
                                                      'C0',
                                                      '',
                                                      1000,0.05,
                                                      'jNeuroML_NEURON',
                                                      verbose=False,
                                                      plot_ca=False)
# Out:
# ********************
#
#    Going to generate c302_C0_Muscles and run for 1000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C0
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Writing generated network to: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_Muscles.nml
# c302      >>>  Finished simulation of LEMS_c302_C0_Muscles.xml and have reloaded results
# ...

# %%
param_overrides = {"neuron_to_muscle_exc_syn_conductance":"4 nS",
                  "neuron_to_muscle_inh_syn_conductance":"12 nS",
                   "neuron_to_muscle_exc_syn_conductance":"6 nS",
                  "neuron_to_muscle_inh_syn_conductance":"2 nS",
                  "neuron_to_neuron_elec_syn_gbase":"0.1 nS"}

run_c302('Muscles','C0','',2000,0.05,'jNeuroML_NEURON',verbose=False,plot_ca=False,param_overrides=param_overrides)
# Out:
# ********************
#
#    Going to generate c302_C0_Muscles and run for 2000 on jNeuroML_NEURON
#
# ********************
# Set default parameters for C0
# c302      >>>  Setting parameter neuron_to_neuron_elec_syn_gbase = 0.1 nS
# c302      >>>  Setting parameter neuron_to_muscle_inh_syn_conductance = 2 nS
# c302      >>>  Setting parameter neuron_to_muscle_exc_syn_conductance = 6 nS
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# Opened Excel file: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/../../../CElegansNeuronTables.xls
# c302      >>>  Writing generated network to: /home/padraig/neuroConstruct/osb/invertebrate/celegans/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C0_Muscles.nml
# c302      >>>  Finished simulation of LEMS_c302_C0_Muscles.xml and have reloaded results
# ...
