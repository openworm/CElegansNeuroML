# %%
# %cd /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302
# Out:
# /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302

# %%
# %matplotlib inline

# %%
# %load c302_MotorToMuscleSynTest.py
import c302
import sys

import neuroml.writers as writers


def setup(parameter_set,
          generate=False,
          duration=400,
          dt=0.05,
          target_directory='examples',
          data_reader="UpdatedSpreadsheetDataReader"):
    
    exec ('from parameters_%s import ParameterisedModel' % parameter_set)
    params = ParameterisedModel()

    #params.set_bioparameter("unphysiological_offset_current", "0pA", "Testing TapWithdrawal", "0")
    params.set_bioparameter("unphysiological_offset_current_del", "0 ms", "Testing TapWithdrawal", "0")
    params.set_bioparameter("unphysiological_offset_current_dur", "2000 ms", "Testing TapWithdrawal", "0")

    cells = ['VA1']
    #cells += ['AVAL']
    #cells += ['DB6']

    muscles_to_include = ['MVL07']

  
    cells_to_stimulate = ['VA1']

    cells_to_plot = cells
    reference = "c302_%s_MotorToMuscleSynTest" % parameter_set

    conns_to_include = [
        'VA1-MVL07'
    ]

    conn_polarity_override = {
      
    }

    conn_number_override = {
        'VA1-MVL07':1
    }

    
    

    if generate:
        nml_doc = c302.generate(reference,
                                params,
                                cells=cells,
                                cells_to_plot=cells_to_plot,
                                cells_to_stimulate=cells_to_stimulate,
                                conns_to_include=conns_to_include,
                                conn_polarity_override=conn_polarity_override,
                                conn_number_override=conn_number_override,
                                muscles_to_include=muscles_to_include,
                                duration=duration,
                                dt=dt,
                                target_directory=target_directory,
                                data_reader=data_reader)


    return cells, cells_to_stimulate, params, muscles_to_include


if __name__ == '__main__':
    parameter_set = sys.argv[1] if len(sys.argv) == 2 else 'C2'

    setup(parameter_set, generate=True, data_reader="UpdatedSpreadsheetDataReader")
# Out:
# Set default parameters for C
# Set default parameters for C2
# c302      >>>
# c302      >>>
# c302      >>> Parameters and setting used to generate this network:
# c302      >>>
# c302      >>>     Data reader:                    UpdatedSpreadsheetDataReader
# c302      >>>     Cells:                          ['VA1']
# c302      >>>     Cell stimulated:                ['VA1']
# c302      >>>     Connection:                     ['VA1-MVL07']
# c302      >>>     Connection numbers overridden:  {'VA1-MVL07': 1}
# c302      >>>     Connection numbers scaled:      None
# c302      >>>     Connection polarities override: {}
# c302      >>>     Muscles:                        ['MVL07']
# c302      >>>
# Opened file: /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# c302      >>>  Loaded morphology: /home/jovyan/packages/CElegansNeuroML/CElegans/generatedNeuroML2/VA1.cell.nml; id: VA1; placing at location: (-1.35, -235.55, 11.75)
# c302      >>>  Finished loading 1 cells
# Opened file: /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/../../../herm_full_edgelist.csv
# c302      >>>  Positioning muscle: MVL07 at (-80,-90,-80)
# c302      >>>  Finished creating 1 muscles
# VA1-MVL07 13 exc Acetylcholine
# c302      >>>  >> Changing number of effective synapses connection VA1 -> MVL07: was: 13 (total cond: 44.98nS), becomes 1 (total cond: 3.460000000000000nS)
# c302      >>>  Writing generated network to: /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C2_MotorToMuscleSynTest.nml
# c302      >>>  Written network file to: examples/c302_C2_MotorToMuscleSynTest.nml
# c302      >>>  Written LEMS file to: examples/LEMS_c302_C2_MotorToMuscleSynTest.xml
# Validating examples/c302_C2_MotorToMuscleSynTest.nml against /opt/conda/envs/python2/lib/python2.7/site-packages/neuroml/nml/NeuroML_v2beta5.xsd
# It's valid!

# %%
# Replace this with your model path.  
# This example is from https://github.com/OpenSourceBrain/IzhikevichModel.
LEMS_MODEL_PATH = '/home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/examples/LEMS_c302_C2_MotorToMuscleSynTest.xml'

# %%
import os,sys
from pyneuroml import pynml

# %%
results = pynml.run_lems_with_jneuroml(os.path.split(LEMS_MODEL_PATH)[1], 
                             verbose=False, load_saved_data=True, nogui=True, 
                             exec_in_dir=os.path.split(LEMS_MODEL_PATH)[0],
                             plot=True)
# Out:
# pyNeuroML >>> Reloading: Data loaded from /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C2_MotorToMuscleSynTest.dat (jNeuroML)
# pyNeuroML >>> Reloading: Data loaded from /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C2_MotorToMuscleSynTest.activity.dat (jNeuroML)
# pyNeuroML >>> Reloading: Data loaded from /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C2_MotorToMuscleSynTest.muscles.dat (jNeuroML)
# pyNeuroML >>> Reloading: Data loaded from /home/jovyan/packages/CElegansNeuroML/CElegans/pythonScripts/c302/examples/c302_C2_MotorToMuscleSynTest.muscles.activity.dat (jNeuroML)
# IndexErrorTraceback (most recent call last)
# <ipython-input-6-b4713c2d95bd> in <module>()
#       3                              verbose=False, load_saved_data=True, nogui=True,
#       4                              exec_in_dir=os.path.split(LEMS_MODEL_PATH)[0],
# ----> 5                              plot=True)
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pyneuroml/pynml.pyc in run_lems_with_jneuroml(lems_file_name, max_memory, nogui, load_saved_data, plot, show_plot_already, exec_in_dir, verbose, exit_on_fail)
#     456                                  show_plot_already=show_plot_already,
#     457                                  simulator='jNeuroML',
# --> 458                                  reload_events=False)
#     459     else:
#     460         return True
#
# /opt/conda/envs/python2/lib/python2.7/site-packages/pyneuroml/pynml.pyc in reload_saved_data(lems_file_name, t_run, plot, show_plot_already, simulator, reload_events, verbose)
#     653             for key in cols:
#     654                 if n_output_files>1:
# --> 655                     ax_ = ax[i]
#     656                 else:
#     657                     ax_ = ax
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
